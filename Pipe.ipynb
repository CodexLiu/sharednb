# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Set the path for the cloned repository in your drive
path_to_your_drive = '/content/drive/My Drive/'  # You can change this path
repo_name = 'DiffDock-PP'
path_to_repo = os.path.join(path_to_your_drive, repo_name)

# Clone the repository
if not os.path.exists(path_to_repo):
    os.makedirs(path_to_repo, exist_ok=True)
    # %cd {path_to_your_drive}
    # !git clone https://github.com/ketatam/DiffDock-PP.git {repo_name}
else:
    print(f"Repository '{repo_name}' already exists at {path_to_repo}")

# Navigate to the repository folder
# %cd {path_to_repo}
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# Cloning into 'DiffDock-PP'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 161 (delta 28), reused 148 (delta 21), pack-reused 0
# Receiving objects: 100% (161/161), 40.64 MiB | 15.11 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Updating files: 100% (114/114), done.
# /content/drive/My Drive/DiffDock-PP

# %%
# !pip install torch==1.13.0+cu116 torchvision==0.14.0+cu116 torchaudio==0.13.0 -f https://download.pytorch.org/whl/cu116/torch_stable.html
# !pip install --no-cache-dir torch-scatter==2.0.9 -f https://data.pyg.org/whl/torch-1.13.0+cu116.html
# !pip install --no-cache-dir torch-sparse==0.6.15 -f https://data.pyg.org/whl/torch-1.13.0+cu116.html
# !pip install --no-cache-dir torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-1.13.0+cu116.html
# !pip install numpy dill tqdm pyyaml pandas biopandas scikit-learn biopython e3nn wandb tensorboard tensorboardX matplotlib
# Out:
# Looking in links: https://download.pytorch.org/whl/cu116/torch_stable.html
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.13.0+cu116.html
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.13.0+cu116.html
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.13.0+cu116.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.3/868.3 kB 77.6 MB/s eta 0:00:00
# ...

# %%
# Install torch_cluster
# !pip install torch-cluster==1.6.0 -f https://data.pyg.org/whl/torch-1.13.0+cu116.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-1.13.0+cu116.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 2.7 MB/s eta 0:00:00
# ...

# %%
# !sh /content/drive/MyDrive/DiffDock-PP/src/db5_inference.sh
# Out:
# SCORE_MODEL_PATH: checkpoints/large_model_dips/fold_0/
# CONFIDENCE_MODEL_PATH: checkpoints/large_model_dips/fold_0/
# SAVE_PATH: ckpts/run_on_pdb_pairs
# /usr/local/lib/python3.10/dist-packages/torch_geometric/typing.py:101: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: libcusparse.so.11: cannot open shared object file: No such file or directory
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# 23:34:55 Starting Inference
# 23:34:55 Using Bound structures
# data loading: 100%|█| 1/1 [00:00<00:00, 15.79it/s]
# 23:34:55 Computing ESM embeddings
# Downloading: "https://github.com/facebookresearch/esm/zipball/main" to torchhub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t33_650M_UR50D.pt" to torchhub/checkpoints/esm2_t33_650M_UR50D.pt
# ...
